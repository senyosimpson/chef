# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def tanh_grad(input, transpose=False):
    grad = 1 - np.power(input, 2)
    if transpose:
        return grad.T
    return grad

# %%
def loss_fn(input, target, grad=False):
    if grad:
        return input - target
    return np.sum(0.5 * np.power(input - target, 2))

# %%
class Layer:
    def __init__(self, n_inputs, n_outputs, activation=None):
        self.w = np.random.randn(n_inputs, n_outputs)
        self.b = np.random.randn(n_outputs, 1)
        self.activation = activation

    def __call__(self, input):
        return self.forward(input)

    def forward(self, input):
        x = np.matmul(self.w.T, input) + self.b
        if self.activation:
            x = self.activation(x)
        return x

# %%
class NeuralNetwork:
    def __init__(self, n_inputs, n_outputs, loss_fn=loss_fn):
        self.layer1 = Layer(n_inputs, 4, np.tanh)
        self.layer2 = Layer(4, n_outputs)
        self.outputs = []
        self.losses = []
        
    def forward(self, input):
        x1 = self.layer1(input)
        x2 = self.layer2(x1)
        self.outputs = [input, x1, x2]
        return x2
    
    def backward(self, delta, lr=1e-3):
        error = np.dot(self.outputs[1], delta.T)
        self.layer2.w = self.layer2.w - lr * error
        self.layer2.b = self.layer2.b - lr * delta
        delta = np.dot(
            tanh_grad(self.outputs[1], transpose=True),
            np.sum(np.dot(self.layer2.w, delta)))
        error = np.dot(self.outputs[0], delta.T)
        self.layer1.w = self.layer1.w - lr * error
        self.layer1.b = self.layer1.b - lr * delta
        
    def __call__(self, input, target):
        x = self.forward(input)
        delta = loss_fn(x, target, grad=True)
        self.losses.append(loss_fn(x, input))
        self.backward(delta)

# %%
np.sum(np.random.randn(4, 1))
# Out:
# ()

# %%
x = np.linspace(0, 1, 32).reshape(-1, 1)
x = np.hstack((x, x))

alpha = np.array([4, 3]).reshape(-1, 1)
beta = 4
y = np.dot(x, alpha) + beta

# %%
model = NeuralNetwork(2, 1)
for epoch in range(100):
    for input, target in zip(x, y):
        input = input.reshape(-1, 1)
        target = target.reshape(-1, 1)
        model(input, target)

# %%
plt.figure(figsize=(12, 5))
plt.plot(np.arange(len(model.losses)), model.losses)
